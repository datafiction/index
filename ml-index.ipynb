# %% [markdown]
# ## Machine Learning

# %% [markdown]
# This page is a collection of sample problems and projects for machine learning using Python, Pandas, Matplotlib, Numpy and Scikit learn libraries

# %% [markdown]
# ### 1. Scikit Learn Examples
#
# ##### 1.1 Linear Model
#
# - [Linear Regression](https://nbviewer.jupyter.org/github/datafiction/sklearn-samples/blob/master/LinearModels/Linear-models.ipynb)
#
# ##### 1.2 Classifiers:
#
#   - [Logistic Regerssion](https://nbviewer.jupyter.org/github/datafiction/sklearn-samples/blob/master/Classifiers/Logistic/Logistic.ipynb)
#   - [Decision Tree](https://nbviewer.jupyter.org/github/datafiction/sklearn-samples/blob/master/Classifiers/Tree/Tree.ipynb)
#   - [Nearest Neighbour](https://nbviewer.jupyter.org/github/datafiction/sklearn-samples/blob/master/Classifiers/Neighbour/Neighbour.ipynb)
#   - [SVM](https://nbviewer.jupyter.org/github/datafiction/sklearn-samples/blob/master/Classifiers/SVM/svm.ipynb)
#   - [Neural Network](https://nbviewer.jupyter.org/github/datafiction/sklearn-samples/blob/master/Classifiers/NN/nn.ipynb)
#
# ##### 1.3 Clustering:
#
#   - [K-means](https://nbviewer.jupyter.org/github/datafiction/sklearn-samples/blob/master/Clustering/1.Kmeans.ipynb)
#   - [Cluster Comperison](https://nbviewer.jupyter.org/github/datafiction/sklearn-samples/blob/master/Clustering/2.Cluster-Comparison.ipynb)
#   - [Agglomerative](https://nbviewer.jupyter.org/github/datafiction/sklearn-samples/blob/master/Clustering/3.Agglomerative.ipynb)
#   - [Mean-Shift](https://nbviewer.jupyter.org/github/datafiction/sklearn-samples/blob/master/Clustering/4.Mean-shift.ipynb)
#   -[Affinity Propagation](https://nbviewer.jupyter.org/github/datafiction/sklearn-samples/blob/master/Clustering/5.Affinity-Propagation.ipynb)
#   - [DBSCAN](https://nbviewer.jupyter.org/github/datafiction/sklearn-samples/blob/master/Clustering/6.DBSCAN.ipynb)
#   - [Spectral](https://nbviewer.jupyter.org/github/datafiction/sklearn-samples/blob/master/Clustering/7.Spectral.ipynb)
#
#
# ---------
#
# ### 2. Udacity Assignments
#
# ##### 2.1 Projects
#
# - [Titanic Survival Exploration](https://nbviewer.jupyter.org/github/Vasuji/MLND-projects/blob/master/titanic_survival_exploration/titanic_survival_exploration.ipynb)
# - [Predicting Boston Housing Prices](https://nbviewer.jupyter.org/github/Vasuji/MLND-projects/blob/master/boston_housing/boston_housing.ipynb)
# - [Finding Donors for CharityML](https://nbviewer.jupyter.org/github/Vasuji/MLND-projects/blob/master/finding_donors/finding_donors.ipynb)
# - [Creating Customer Segments](https://nbviewer.jupyter.org/github/Vasuji/MLND-projects/blob/master/Customer_segments/customer_segments.ipynb)
#
# ##### 2.2 Capstone Project: Vahicle Detection:
#   - [Data Exploration](https://nbviewer.jupyter.org/github/Vasuji/MLND-capstone/blob/master/I-Explore-data.ipynb)
#   - [Feature Extraction](https://nbviewer.jupyter.org/github/Vasuji/MLND-capstone/blob/master/II-Feature-extraction.ipynb)
#   - [Parameter Tuning - SVM](https://nbviewer.jupyter.org/github/Vasuji/MLND-capstone/blob/master/III-Parameter-tuning-svm.ipynb)
#   - [Parameter Tuning - NN](https://nbviewer.jupyter.org/github/Vasuji/MLND-capstone/blob/master/III-Parameter-tuning-svm.ipynb)
#   - [SVM - Model Implementation](https://nbviewer.jupyter.org/github/Vasuji/MLND-capstone/blob/master/IV-Apply-model-svm.ipynb)
#   - [NN - Model Implementation](https://nbviewer.jupyter.org/github/Vasuji/MLND-capstone/blob/master/IV-Apply-model-nn.ipynb)
#
# ------
#
# ### 3. Machine Learning Graphlab
#
# ##### 3.1 ML Foundation
#
# - [1.1-Getting-started-with-iPython-Notebook](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/1.%20ML-Foundation/1.1-Getting-started-with-iPython-Notebook.ipynb)
# - [1.2-Getting-Started-with-SFrames](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/1.%20ML-Foundation/1.2-Getting-Started-with-SFrames.ipynb)
# - [2-Predicting-House-Prices](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/1.%20ML-Foundation/2-Predicting-House-Prices.ipynb)
# - [3-Analyzing-Product-Sentiment](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/1.%20ML-Foundation/3-Analyzing-Product-Sentiment.ipynb)
# - [4-Document Retrieval](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/1.%20ML-Foundation/4-Document%20Retrieval.ipynb)
# - [5-Song Recommender.ipynb](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/1.%20ML-Foundation/5-Song%20Recommender.ipynb)
# - [6.1-Deep Features for Image Classification](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/1.%20ML-Foundation/6.1-Deep%20Features%20for%20Image%20Classification.ipynb)
# - [6.2-Deep Features for Image Retrieval](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/1.%20ML-Foundation/6.2-Deep%20Features%20for%20Image%20Retrieval.ipynb)
#
# ##### 3.2 MLRegression
#
# - [1-simple-regression](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/2.%20ML-Regresssion/1-simple-regression.ipynb)
# - [2.1-multiple-regression-interpretation](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/2.%20ML-Regresssion/2.1-multiple-regression-interpretation.ipynb)
# - [2.2-multiple-regression-gradient_descent](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/2.%20ML-Regresssion/2.2-multiple-regression-gradient_descent.ipynb)
# - [3-assessing-performance](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/2.%20ML-Regresssion/3-assessing-performance.ipynb)
# - [4.1-ridge-regression-interpretation](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/2.%20ML-Regresssion/4.1-ridge-regression-interpretation.ipynb)
# - [4.2-ridge-regression-gradient-descent](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/2.%20ML-Regresssion/4.2-ridge-regression-gradient-descent.ipynb)
# - [5.1-overfitting-demo-ridge-lasso](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/2.%20ML-Regresssion/5.1-overfitting-demo-ridge-lasso.ipynb)
# - [5.2-lasso-interpretation](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/2.%20ML-Regresssion/5.2-lasso-interpretation.ipynb)
# - [5.3-lasso-coordinate-descent](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/2.%20ML-Regresssion/5.3-lasso-coordinate-descent.ipynb)
# - [6-local-regression.ipynb](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/2.%20ML-Regresssion/6-local-regression.ipynb)
#
# ##### 3.3 Classification
#
# - [module-02-linear-classifier](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/3.%20ML-Classification/module-02-linear-classifier.ipynb)
# - [module-03-linear-classifier-learning](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/3.%20ML-Classification/module-03-linear-classifier-learning.ipynb)
# - [module-04-linear-classifier-regularization](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/3.%20ML-Classification/module-04-linear-classifier-regularization.ipynb)
# - [module-05.1-decision-tree-identifying](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/3.%20ML-Classification/module-05.1-decision-tree-identifying.ipynb)
# - [module-05.2-decision-tree-learning](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/3.%20ML-Classification/module-05.2-decision-tree-learning.ipynb)
# - [module-06-decision-tree-practical](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/3.%20ML-Classification/module-06-decision-tree-practical.ipynb)
# - [module-08.1-boosting-exploration](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/3.%20ML-Classification/module-08.1-boosting-exploration.ipynb)
# - [module-08.2-boosting-a-decison_stump](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/3.%20ML-Classification/module-08.2-boosting-a-decison_stump.ipynb)
# - [module-09-precision-recall](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/3.%20ML-Classification/module-09-precision-recall.ipynb)
# - [module-10-online-learning](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/3.%20ML-Classification/module-10-online-learning.ipynb)
#
#
#
# ##### 3.4 Clustering
#
# - [0_nearest-neighbors-features-and-metrics](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/4.%20ML-Clustering/0_nearest-neighbors-features-and-metrics.ipynb)
# - [1_nearest-neighbors-lsh-implementation](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/4.%20ML-Clustering/1_nearest-neighbors-lsh-implementation.ipynb)
# - [2_kmeans-with-text-data](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/4.%20ML-Clustering/2_kmeans-with-text-data.ipynb)
# - [3_em-for-gmm.ipynb](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/4.%20ML-Clustering/3_em-for-gmm.ipynb)
# - [4_em-with-text-data](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/4.%20ML-Clustering/4_em-with-text-data.ipynb)
# - [5_lda](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/4.%20ML-Clustering/5_lda.ipynb)
# - [6_hierarchical_clustering](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-graphlab/blob/master/4.%20ML-Clustering/6_hierarchical_clustering.ipynb)
#
# ----------

# %% [markdown]
# #### References
#
#
# 1. [Machine Learning Examples and videos collection](https://github.com/Vasuji/Machine-Learning)
# 2. [A curated list of awesome Machine Learning frameworks, libraries and software](https://github.com/datafiction/awesome-machine-learning)
# 3. [Learn Data Science](http://learnds.com/)
# 4. [Machine Learning Tutorials](https://nbviewer.jupyter.org/github/temporaer/tutorial_ml_gkbionics/tree/master/)
# 5. [A data analysis sample](https://nbviewer.jupyter.org/github/rhiever/Data-Analysis-and-Machine-Learning-Projects/blob/master/example-data-science-notebook/Example%20Machine%20Learning%20Notebook.ipynb)
# 6. [Machine learning and deep learning tutorials, articles and other resources](http://ujjwalkarn.github.io/Machine-Learning-Tutorials/)
# 7. [Python examples of popular machine learning algorithms with interactive Jupyter demos and math being explained](https://github.com/trekhleb/homemade-machine-learning)
# 8. [Machine Learning Notebooks](https://nbviewer.jupyter.org/github/datafiction/Machine-Learning-with-Python/tree/master/)
